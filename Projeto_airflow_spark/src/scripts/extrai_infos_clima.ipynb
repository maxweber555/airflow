# %%
import os
from os.path import join
import pandas as pd
from datetime import datetime, timedelta

# %%
# intervalo de datas
data_inicio = datetime.today()
data_fim = data_inicio + timedelta(days=7)

#formatando as datas
data_inicio = data_inicio.strftime('%Y-%m-%d')
data_fim = data_fim.strftime('%Y-%m-%d')

city = 'Boston'
key = '5S8MK3KWENHMVZ8M723LU2539'

# %%
url =join('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/'
          f'{city}/{data_inicio}/{data_fim}?unitGroup=metric&include=days&key={key}&contentType=csv')

# %%
dados = pd.read_csv(url)

# %%
dados.head(5)
# Out:
#                         name    datetime  tempmax  tempmin  temp  \
# 0  Boston, MA, United States  2025-01-22     -6.6    -12.7  -9.1
# 1  Boston, MA, United States  2025-01-23     -1.1     -8.3  -5.0
# 2  Boston, MA, United States  2025-01-24     -1.6     -6.1  -4.2
# 3  Boston, MA, United States  2025-01-25     -1.9     -9.1  -5.2
# 4  Boston, MA, United States  2025-01-26      1.9     -3.6  -0.9
#
#    feelslikemax  feelslikemin  feelslike   dew  humidity  ...  solarenergy  \
# 0         -11.6         -20.1      -15.2 -18.5      46.3  ...         21.8
# 1          -5.4         -13.6       -9.8 -11.2      62.0  ...          7.9
# 2          -6.7         -11.9       -9.4 -10.9      59.8  ...         10.7
# 3          -6.7         -14.3      -10.1 -12.1      58.5  ...         11.2
# 4          -2.6          -8.8       -5.7  -7.2      62.4  ...          9.0
#
#    uvindex  severerisk              sunrise               sunset  moonphase  \
# 0        5          10  2025-01-22T07:06:31  2025-01-22T16:45:51       0.78
# 1        4          10  2025-01-23T07:05:46  2025-01-23T16:47:07       0.81
# 2        3          10  2025-01-24T07:04:59  2025-01-24T16:48:24       0.85
# 3        3          10  2025-01-25T07:04:10  2025-01-25T16:49:41       0.88
# 4        3          10  2025-01-26T07:03:19  2025-01-26T16:50:58       0.91
#
#          conditions                           description               icon  \
# 0  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 1  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 2             Clear  Clear conditions throughout the day.          clear-day
# 3  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 4  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
#
#                      stations
# 0  KOWD,AV085,KBED,0518W,KBOS
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 33 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              8 non-null      object
#  1   datetime          8 non-null      object
#  2   tempmax           8 non-null      float64
#  3   tempmin           8 non-null      float64
#  4   temp              8 non-null      float64
#  5   feelslikemax      8 non-null      float64
#  6   feelslikemin      8 non-null      float64
#  7   feelslike         8 non-null      float64
#  8   dew               8 non-null      float64
#  9   humidity          8 non-null      float64
#  10  precip            8 non-null      float64
#  11  precipprob        8 non-null      float64
#  12  precipcover       8 non-null      float64
#  13  preciptype        4 non-null      object
#  14  snow              8 non-null      float64
#  15  snowdepth         8 non-null      float64
#  16  windgust          8 non-null      float64
#  17  windspeed         8 non-null      float64
#  18  winddir           8 non-null      float64
#  19  sealevelpressure  8 non-null      float64
#  20  cloudcover        8 non-null      float64
#  21  visibility        8 non-null      float64
#  22  solarradiation    8 non-null      float64
#  23  solarenergy       8 non-null      float64
#  24  uvindex           8 non-null      int64
#  25  severerisk        8 non-null      int64
#  26  sunrise           8 non-null      object
#  27  sunset            8 non-null      object
#  28  moonphase         8 non-null      float64
#  29  conditions        8 non-null      object
#  30  description       8 non-null      object
#  31  icon              8 non-null      object
#  32  stations          1 non-null      object
# dtypes: float64(22), int64(2), object(9)
# memory usage: 2.2+ KB

# %%
file_path = f'/home/maxweber/Notbook/Apache_airflow/semana={data_inicio}/'
os.mkdir(file_path)

dados.to_csv(file_path + 'dados_brutos.csv')
dados[['datetime', 'tempmax', 'temp','tempmax']].to_csv(file_path + 'temperatura.csv')
dados[['datetime', 'description', 'icon']].to_csv(file_path + 'condicoes.csv')
