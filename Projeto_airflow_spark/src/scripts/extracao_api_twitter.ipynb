# %%
import requests
from datetime import datetime, timedelta
import json
import pandas as pd

# %%
#montando url
TIMESTAMP_FORMAT = "%Y-%m-%dT%H:%M:%S.00Z"

end_time = datetime.now().strftime(TIMESTAMP_FORMAT)
start_time = (datetime.now() + timedelta(-1)).date().strftime(TIMESTAMP_FORMAT)
query = "data science"

tweet_fields = "tweet.fields=author_id,conversation_id,created_at,id,in_reply_to_user_id,public_metrics,lang,text"
user_fields = "expansions=author_id&user.fields=id,name,username,created_at"

url_raw = f"https://labdados.com/2/tweets/search/recent?query={query}&{tweet_fields}&{user_fields}&start_time={start_time}&end_time={end_time}"

# %%
bearer_token = ''
headers = {"Authorization": "Bearer {}".format(bearer_token)}
response = requests.request("GET", url_raw)

# %%
json_response = response.json()
#print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
# paginate
while "next_token" in json_response.get("meta",{}):
    next_token = json_response['meta']['next_token']
    url = f"{url_raw}&next_token={next_token}"
    response = requests.request("GET", url, headers=headers)
    json_response = response.json()
    print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "author_id": "56",
#             "conversation_id": "52",
#             "created_at": "2025-01-28T00:23:48.639598+0000",
#             "edit_history_tweet_ids": [
#                 56
#             ],
#             "id": "6",
#             "in_reply_to_user_id": "71",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 82,
#                 "quote_count": 88,
#                 "reply_count": 52,
#                 "retweet_count": 28
#             },
#             "text": "Este \u00e9 um tweet fict\u00edcio sobre data science"
#         },
#         {
#             "author_id": "66",
#             "conversation_id": "7",
#             "created_at": "2025-01-28T18:55:26.231464+0000",
#             "edit_history_tweet_ids": [
#                 10
#             ],
#             "id": "78",
#             "in_reply_to_user_id": "86",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 31,
#                 "quote_count": 7,
#                 "reply_count": 51,
#                 "retweet_count": 97
#             },
#             "text": "Este \u00e9 um tweet fict\u00edcio sobre data science"
#         },
#         {
#             "author_id": "23",
#             "conversation_id": "7",
#             "created_at": "2025-01-28T08:43:59.529153+0000",
#             "edit_history_tweet_ids": [
#                 51
#             ],
#             "id": "69",
#             "in_reply_to_user_id": "39",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 41,
#                 "quote_count": 81,
#                 "reply_count": 64,
#                 "retweet_count": 76
#             },
#             "text": "Tweet fict\u00edcio criado usando intelig\u00eancia artificial para falar sobre data science"
#         },
#         {
#             "author_id": "71",
#             "conversation_id": "79",
#             "created_at": "2025-01-28T19:27:44.637654+0000",
#             "edit_history_tweet_ids": [
#                 77
#             ],
#             "id": "60",
#             "in_reply_to_user_id": "41",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 70,
#                 "quote_count": 66,
#                 "reply_count": 31,
#                 "retweet_count": 0
#             },
#             "text": "Tweet fict\u00edcio criado usando intelig\u00eancia artificial para falar sobre data science"
#         },
#         {
#             "author_id": "95",
#             "conversation_id": "57",
#             "created_at": "2025-01-28T20:27:42.599825+0000",
#             "edit_history_tweet_ids": [
#                 70
#             ],
#             "id": "82",
#             "in_reply_to_user_id": "79",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 10,
#                 "quote_count": 22,
#                 "reply_count": 13,
#                 "retweet_count": 28
#             },
#             "text": "Um terceiro tweet fict\u00edcio sobre data science"
#         },
#         {
#             "author_id": "53",
#             "conversation_id": "48",
#             "created_at": "2025-01-28T11:37:32.589670+0000",
#             "edit_history_tweet_ids": [
#                 0
#             ],
#             "id": "79",
#             "in_reply_to_user_id": "94",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 23,
#                 "quote_count": 99,
#                 "reply_count": 66,
#                 "retweet_count": 44
#             },
#             "text": "Outro tweet fict\u00edcio relacionado a data science"
#         },
#         {
#             "author_id": "27",
#             "conversation_id": "13",
#             "created_at": "2025-01-29T07:56:44.956370+0000",
#             "edit_history_tweet_ids": [
#                 55
#             ],
#             "id": "5",
#             "in_reply_to_user_id": "24",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 55,
#                 "quote_count": 36,
#                 "reply_count": 77,
#                 "retweet_count": 73
#             },
#             "text": "Outro tweet fict\u00edcio relacionado a data science"
#         },
#         {
#             "author_id": "8",
#             "conversation_id": "49",
#             "created_at": "2025-01-29T00:07:18.866182+0000",
#             "edit_history_tweet_ids": [
#                 57
#             ],
#             "id": "11",
#             "in_reply_to_user_id": "54",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 74,
#                 "quote_count": 47,
#                 "reply_count": 28,
#                 "retweet_count": 72
#             },
#             "text": "Tweet fict\u00edcio gerado automaticamente sobre data science"
#         },
#         {
#             "author_id": "61",
#             "conversation_id": "75",
#             "created_at": "2025-01-28T06:01:50.294904+0000",
#             "edit_history_tweet_ids": [
#                 12
#             ],
#             "id": "53",
#             "in_reply_to_user_id": "64",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 93,
#                 "quote_count": 13,
#                 "reply_count": 39,
#                 "retweet_count": 21
#             },
#             "text": "Um terceiro tweet fict\u00edcio sobre data science"
#         },
#         {
#             "author_id": "11",
#             "conversation_id": "54",
#             "created_at": "2025-01-28T00:37:46.456801+0000",
#             "edit_history_tweet_ids": [
#                 93
#             ],
#             "id": "100",
#             "in_reply_to_user_id": "38",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 25,
#                 "reply_count": 89,
#                 "retweet_count": 22
#             },
#             "text": "Tweet fict\u00edcio gerado automaticamente sobre data science"
#         }
#     ],
#     "includes": {
#         "users": [
#             {
#                 "created_at": "2025-01-28T09:58:18.836120+0000",
#                 "id": "65",
#                 "name": "User 1",
#                 "username": "user1"
#             },
#             {
#                 "created_at": "2025-01-28T00:46:09.410738+0000",
#                 "id": "36",
#                 "name": "User 2",
#                 "username": "user2"
#             },
#             {
#                 "created_at": "2025-01-28T22:36:52.681182+0000",
#                 "id": "53",
#                 "name": "User 3",
#                 "username": "user3"
#             },
#             {
#                 "created_at": "2025-01-29T09:57:15.775237+0000",
#                 "id": "42",
#                 "name": "User 4",
#                 "username": "user4"
#             },
#             {
#                 "created_at": "2025-01-29T03:30:22.872937+0000",
#                 "id": "26",
#                 "name": "User 5",
#                 "username": "user5"
#             },
#             {
#                 "created_at": "2025-01-28T00:07:57.468127+0000",
#                 "id": "60",
#                 "name": "User 6",
#                 "username": "user6"
#             },
#             {
#                 "created_at": "2025-01-29T00:03:46.059304+0000",
#                 "id": "15",
#                 "name": "User 7",
#                 "username": "user7"
#             },
#             {
#                 "created_at": "2025-01-28T00:11:01.231480+0000",
#                 "id": "88",
#                 "name": "User 8",
#                 "username": "user8"
#             },
#             {
#                 "created_at": "2025-01-28T17:01:29.212647+0000",
#                 "id": "21",
#                 "name": "User 9",
#                 "username": "user9"
#             },
#             {
#                 "created_at": "2025-01-29T09:19:44.315285+0000",
#                 "id": "93",
#                 "name": "User 10",
#                 "username": "user10"
#             }
#         ]
#     }
# }
